# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexanderVieira/training_datascience/blob/main/AirPassengers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
data = pd.read_csv('https://raw.githubusercontent.com/AileenNielsen/TimeSeriesAnalysisWithPython/master/data/AirPassengers.csv')

# %%
data.set_index("Month", inplace=True)

# %%
data.index = pd.to_datetime(data.index)

fig, ax= plt.subplots(1, 1, figsize=(20, 6))
sns.set_style("ticks")
sns.set_context("talk")

data.plot(ax=ax)
ax.yaxis.grid(True)
sns.despine(offset=5, trim=True)

# %%
result = seasonal_decompose(data["#Passengers"], freq=12, model="multiplicative")

# %%
result.trend.plot()

# %%
result.seasonal.plot()

# %%
result.resid.plot()
